# %% [markdown]
# <h1 style="text-align:center;">Etape 3: Modélisation </h1>

# %% [markdown]
# # 1. Importation des packages

# %%
import pandas as pd

import numpy as np   # Importe la bibliothèque numpy pour la manipulation de tableaux (arrays).

from sklearn.model_selection import train_test_split  # Importe la fonction train_test_split pour diviser les données en ensembles d'entraînement et de test.
#Model
from sklearn.tree import DecisionTreeRegressor  # Importe le modèle de régression par arbre de décision.
from sklearn.ensemble import RandomForestRegressor  # Importe le modèle de régression par forêt aléatoire.
from sklearn.ensemble import GradientBoostingRegressor  # Importe le modèle de régression par Gradient Boosting Regressor.
from sklearn.linear_model import LinearRegression, Lasso  # Importe les modèles de régression linéaire et de régression Lasso.
from sklearn.linear_model import ElasticNet

#metrique
from sklearn.metrics import classification_report, confusion_matrix  # Importe des métriques pour évaluer les performances des modèles.
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Importe GridSearchCV pour effectuer une recherche des meilleurs hyperparamètres et ShuffleSplit pour diviser les données en ensembles de validation.
from sklearn.model_selection import GridSearchCV, ShuffleSplit

import matplotlib.pyplot as plt  # Importe la bibliothèque matplotlib pour la visualisation de données.
import seaborn as sns  # Importe la bibliothèque seaborn pour la visualisation de données basée sur matplotlib.

from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
import mlflow
import datetime
import warnings

pd.options.display.max_columns = None
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler  # Importe StandardScaler pour la normalisation des données.

# %% [markdown]
# # 2. Configuration MLFlow

# %%
version = "v1.0"
data_url = "data_cleaned.csv"

# %%
import os
os.environ['MLFLOW_TRACKING_USERNAME']= "WajihHlaili"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "WajihHlaili888"


#setup mlflow
mlflow.set_tracking_uri('https://dagshub.com/WajihHlaili/my-first-repo.mlflow')
mlflow.set_experiment("CarPricePrediction_mlFlow-experiment")
# Out:
# 2024/12/07 22:01:36 INFO mlflow.tracking.fluent: Experiment with name 'CarPricePrediction_mlFlow-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/42e87a96dccf4c2193bb7c072066aebc', creation_time=1733605298818, experiment_id='0', last_update_time=1733605298818, lifecycle_stage='active', name='CarPricePrediction_mlFlow-experiment', tags={}>

# %% [markdown]
# # 2. charger des données

# %%
# Charger données
data = pd.read_csv("data_cleaned.csv")
# visualization des données
data.head()
# Out:
#      year  selling_price  km_driven  fuel  transmission  owner  engine  \
# 0  2014.0       450000.0   145500.0     1             2      0  1248.0
# 1  2014.0       370000.0   120000.0     1             2      1  1498.0
# 2  2010.0       225000.0   127000.0     1             2      0  1396.0
# 3  2017.0       440000.0    45000.0     2             2      0  1197.0
# 4  2011.0       350000.0    90000.0     1             2      0  1364.0
#
#    max_power
# 0      74.00
# 1     103.52
# 2      90.00
# 3      81.86
# 4      67.10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6475 entries, 0 to 6474
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           6475 non-null   float64
#  1   selling_price  6475 non-null   float64
#  2   km_driven      6475 non-null   float64
#  3   fuel           6475 non-null   int64
#  4   transmission   6475 non-null   int64
#  5   owner          6475 non-null   int64
#  6   engine         6475 non-null   float64
#  7   max_power      6475 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 404.8 KB

# %% [markdown]
# # 3.Explanation
#
# Pour créer un modèle de prédiction de prix de voiture, il faut suivre plusieurs étapes clés :
#
#     1. Séparation des données : Divisez vos données en ensembles d'apprentissage (pour former le modèle) et de test (pour évaluer sa performance). Une règle courante est de réserver environ 70-80 % des données pour l'apprentissage et le reste pour les tests.
#
#     2. Choix du modèle : Il existe différents types de modèles de prédiction, tels que les régressions linéaires, les réseaux de neurones, les arbres de décision, etc. Sélectionnez le modèle qui convient le mieux à votre problème, en fonction de la nature de vos données et de vos objectifs.
#
#     3. Entraînement du modèle : Utilisez l'ensemble d'apprentissage pour entraîner votre modèle. Le modèle apprendra à partir des données et ajustera ses paramètres pour minimiser l'erreur de prédiction.
#
#     4.Validation et ajustement : Évaluez la performance de votre modèle en utilisant l'ensemble de test. Si les performances ne sont pas satisfaisantes, vous pouvez ajuster les hyperparamètres du modèle ou envisager d'utiliser un modèle différent.

# %% [markdown]
# # 4. Séparation des données

# %%
X = data.drop(columns='selling_price', axis=1)
Y = data['selling_price']

# %%
X
# Out:
#         year  km_driven  fuel  transmission  owner  engine  max_power
# 0     2014.0   145500.0     1             2      0  1248.0      74.00
# 1     2014.0   120000.0     1             2      1  1498.0     103.52
# 2     2010.0   127000.0     1             2      0  1396.0      90.00
# 3     2017.0    45000.0     2             2      0  1197.0      81.86
# 4     2011.0    90000.0     1             2      0  1364.0      67.10
# ...      ...        ...   ...           ...    ...     ...        ...
# 6470  2014.0    80000.0     1             2      1  1396.0      88.73
# 6471  2013.0   110000.0     2             2      0  1197.0      82.85
# 6472  2009.0   120000.0     1             2      0  1248.0      73.90
# 6473  2013.0    25000.0     1             2      0  1396.0      70.00
# 6474  2013.0    25000.0     1             2      0  1396.0      70.00
#
# [6475 rows x 7 columns]

# %%
Y
# Out:
# 0       450000.0
# 1       370000.0
# 2       225000.0
# 3       440000.0
# 4       350000.0
#           ...
# 6470    475000.0
# 6471    320000.0
# 6472    382000.0
# 6473    290000.0
# 6474    290000.0
# Name: selling_price, Length: 6475, dtype: float64

# %% [markdown]
# ### b. Splitting the data into Training data & Test Data

# %%
np.random.seed(42)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
# Verifier X_train , X_test forme
X_train.shape, X_test.shape
# Out:
# ((5180, 7), (1295, 7))

# %%
# Verifier Y_train , Y_test forme
Y_train.shape, Y_test.shape
# Out:
# ((5180,), (1295,))

# %% [markdown]
# # 5. Choix du modèle
#
# Maintenant que nos données sont réparties entre les ensembles d'entraînement et de test, il est temps de construire un modèle d'apprentissage automatique.
#
# nous allons l'entraîner (trouver les modèles) sur l'ensemble d'apprentissage
#
# Et nous allons le tester (utiliser les modèles) sur l'ensemble de test.
#
# Nous allons choisir l'un des trois modèles d'apprentissage automatique suivants :
#
# 1. Linear Regression
# 2. Decision Tree Regressor
# 3. Random Forest Regressor
# 4. Gradient Boosting Regression

# %%
mlflow.sklearn.autolog(disable=True)

# %%
# Put models in a dictionnary
models = {"Linear Regression": LinearRegression(),
         "Decision Tree Regressor": DecisionTreeRegressor(),
         "Random Forest Regressor": RandomForestRegressor(),
         "Gradient Boosting Regression":GradientBoostingRegressor(learning_rate=0.1, n_estimators=500, random_state=0)}


# Create a function to fit and score models
def fit_and_score(models, X_train, X_test, Y_train, Y_test):
    """
    Fits and evaluates given machine learning models
    models: a dict of different Scikit-Learn machine learning models
    X_train: training data (no labels)
    X_test: testing data (no labels)
    Y_train : training labels
    Y_test : test labels
    """
    # Set random seed
    np.random.seed(42)
    #Make a dictionary to keep models scores
    model_scores = {}
    # loop through Models
    for name, model in models.items():
        with mlflow.start_run(run_name=name):
            mlflow.log_param("data_url",data_url)
            mlflow.log_param("data_version",version)
            mlflow.log_param("input_rows",data.shape[0])
            mlflow.log_param("input_cols",data.shape[1])
            #model fitting and training
            mlflow.set_tag(key= "model",value=name)
            params = model.get_params()
            mlflow.log_params(params)
            model.fit(X_train, Y_train)
            train_features_name = f'{X_train=}'.split('=')[0]
            train_label_name = f'{Y_train=}'.split('=')[0]
            mlflow.set_tag(key="train_features_name",value= train_features_name)
            mlflow.set_tag(key= "train_label_name",value=train_label_name)
            predicted=model.predict(X_train)
            # Assuming y_true contains true target values and y_pred contains predicted target values
            mae = mean_absolute_error(Y_train, predicted)
            mse = mean_squared_error(Y_train, predicted)
            rmse = np.sqrt(mse)
            r2 = r2_score(Y_train, predicted)
            Accuracy =  model.score(X_test, Y_test)
            mlflow.log_metric("Accuracy",Accuracy)
            mlflow.log_metric("MAE",mae)
            mlflow.log_metric("MSE",mse)
            mlflow.log_metric("RMSE",rmse)
            mlflow.log_metric("R2",r2)
            mlflow.sklearn.log_model(model,artifact_path="ML_models")

# %%
fit_and_score(models, X_train, X_test, Y_train, Y_test)
# Out:
# 2024/12/07 22:10:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Linear Regression at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/13d0a7cec2b942e085e463ba28ebfd19
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:11:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Decision Tree Regressor at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/48a6cac8763c49f88f8df96798bae95b
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:11:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest Regressor at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/a492256eadbe4c088323bcf9525da7ab
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:19:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Gradient Boosting Regression at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/c89eafeece5f4c8b8e702a8eefc137a9
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0

# %%
#Reading Pandas Dataframe from mlflow
all_experiments = [exp.experiment_id for exp in mlflow.search_experiments()]
df_mlflow = mlflow.search_runs(experiment_ids=all_experiments,filter_string="metrics.Accuracy <1")
run_id = df_mlflow.loc[df_mlflow['metrics.Accuracy'].idxmax()]['run_id']
print(run_id)
# Out:
# c89eafeece5f4c8b8e702a8eefc137a9

# %%
df_mlflow
# Out:
#                              run_id experiment_id    status  \
# 0  c89eafeece5f4c8b8e702a8eefc137a9             0  FINISHED
# 1  a492256eadbe4c088323bcf9525da7ab             0  FINISHED
# 2  48a6cac8763c49f88f8df96798bae95b             0  FINISHED
# 3  13d0a7cec2b942e085e463ba28ebfd19             0  FINISHED
# 4  cae0f23619ae40398309d829e809d599             0    FAILED
# 5  9bb00c896c3243a9856198374f461027             0  FINISHED
# 6  cebf468924d945bf90f50797a29650cf             0  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 1  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 2  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 3  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 4  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 5  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 6  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
#
#                         start_time                         end_time  \
# 0 2024-12-07 21:19:34.510000+00:00 2024-12-07 21:19:57.759000+00:00
# 1 2024-12-07 21:11:32.861000+00:00 2024-12-07 21:19:34.015000+00:00
# 2 2024-12-07 21:11:01.074000+00:00 2024-12-07 21:11:32.290000+00:00
# 3 2024-12-07 21:10:42.934000+00:00 2024-12-07 21:11:00.568000+00:00
# 4 2024-12-07 21:02:29.667000+00:00 2024-12-07 21:09:01.854000+00:00
# 5 2024-12-07 21:02:00.166000+00:00 2024-12-07 21:02:29.155000+00:00
# 6 2024-12-07 21:01:38.284000+00:00 2024-12-07 21:01:59.662000+00:00
#
#     metrics.MAE  metrics.Accuracy   metrics.RMSE   metrics.MSE  metrics.R2  \
# 0  49623.023132          0.894397   68117.703049  4.640021e+09    0.909106
# 1  23367.113732          0.883039   34615.297654  1.198219e+09    0.976528
# 2   6479.951804          0.808349   21530.457438  4.635606e+08    0.990919
# 3  95538.933626          0.730273  120960.509958  1.463144e+10    0.713383
# 4  23367.113732          0.883039   34615.297654  1.198219e+09    0.976528
# 5   6479.951804          0.808349   21530.457438  4.635606e+08    0.990919
# 6  95538.933626          0.730273  120960.509958  1.463144e+10    0.713383
#
#     params.data_url params.random_state params.tol params.validation_fraction  \
# 0  data_cleaned.csv                   0     0.0001                        0.1
# 1  data_cleaned.csv                None       None                       None
# 2  data_cleaned.csv                None       None                       None
# 3  data_cleaned.csv                None       None                       None
# 4  data_cleaned.csv                None       None                       None
# 5  data_cleaned.csv                None       None                       None
# 6  data_cleaned.csv                None       None                       None
#
#   params.verbose params.min_weight_fraction_leaf params.max_depth  \
# 0              0                             0.0                3
# 1              0                             0.0             None
# 2           None                             0.0             None
# 3           None                            None             None
# 4              0                             0.0             None
# 5           None                             0.0             None
# 6           None                            None             None
#
#   params.max_features params.ccp_alpha params.criterion  \
# 0                None              0.0     friedman_mse
# 1                 1.0              0.0    squared_error
# 2                None              0.0    squared_error
# 3                None             None             None
# 4                 1.0              0.0    squared_error
# 5                None              0.0    squared_error
# 6                None             None             None
#
#   params.min_samples_leaf params.min_samples_split params.subsample  \
# 0                       1                        2              1.0
# 1                       1                        2             None
# 2                       1                        2             None
# 3                    None                     None             None
# 4                       1                        2             None
# 5                       1                        2             None
# 6                    None                     None             None
#
#      params.loss params.max_leaf_nodes params.data_version  \
# 0  squared_error                  None                v1.0
# 1           None                  None                v1.0
# 2           None                  None                v1.0
# 3           None                  None                v1.0
# 4           None                  None                v1.0
# 5           None                  None                v1.0
# 6           None                  None                v1.0
#
#   params.n_iter_no_change params.input_rows params.init params.alpha  \
# 0                    None              6475        None          0.9
# 1                    None              6475        None         None
# 2                    None              6475        None         None
# 3                    None              6475        None         None
# 4                    None              6475        None         None
# 5                    None              6475        None         None
# 6                    None              6475        None         None
#
#   params.min_impurity_decrease params.n_estimators params.learning_rate  \
# 0                          0.0                 500                  0.1
# 1                          0.0                 100                 None
# 2                          0.0                None                 None
# 3                         None                None                 None
# 4                          0.0                 100                 None
# 5                          0.0                None                 None
# 6                         None                None                 None
#
#   params.warm_start params.input_cols params.monotonic_cst params.bootstrap  \
# 0             False                 8                 None             None
# 1             False                 8                 None             True
# 2              None                 8                 None             None
# 3              None                 8                 None             None
# 4             False                 8                 None             True
# 5              None                 8                 None             None
# 6              None                 8                 None             None
#
#   params.oob_score params.max_samples params.n_jobs params.splitter  \
# 0             None               None          None            None
# 1            False               None          None            None
# 2             None               None          None            best
# 3             None               None          None            None
# 4            False               None          None            None
# 5             None               None          None            best
# 6             None               None          None            None
#
#   params.copy_X params.fit_intercept params.positive tags.train_features_name  \
# 0          None                 None            None                  X_train
# 1          None                 None            None                  X_train
# 2          None                 None            None                  X_train
# 3          True                 True           False                  X_train
# 4          None                 None            None                  X_train
# 5          None                 None            None                  X_train
# 6          True                 True           False                  X_train
#
#                      tags.model tags.train_label_name  \
# 0  Gradient Boosting Regression               Y_train
# 1       Random Forest Regressor               Y_train
# 2       Decision Tree Regressor               Y_train
# 3             Linear Regression               Y_train
# 4       Random Forest Regressor               Y_train
# 5       Decision Tree Regressor               Y_train
# 6             Linear Regression               Y_train
#
#                              tags.mlflow.source.name  \
# 0  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 1  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 2  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 3  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 4  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 5  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 6  C:\Users\wajih\AppData\Roaming\Python\Python31...
#
#                        tags.mlflow.log-model.history tags.mlflow.user  \
# 0  [{"run_id": "c89eafeece5f4c8b8e702a8eefc137a9"...      wajihhlaili
# 1  [{"run_id": "a492256eadbe4c088323bcf9525da7ab"...      wajihhlaili
# 2  [{"run_id": "48a6cac8763c49f88f8df96798bae95b"...      wajihhlaili
# 3  [{"run_id": "13d0a7cec2b942e085e463ba28ebfd19"...      wajihhlaili
# 4                                               None      wajihhlaili
# 5  [{"run_id": "9bb00c896c3243a9856198374f461027"...      wajihhlaili
# 6  [{"run_id": "cebf468924d945bf90f50797a29650cf"...      wajihhlaili
#
#             tags.mlflow.runName tags.mlflow.source.type
# 0  Gradient Boosting Regression                   LOCAL
# 1       Random Forest Regressor                   LOCAL
# 2       Decision Tree Regressor                   LOCAL
# 3             Linear Regression                   LOCAL
# 4       Random Forest Regressor                   LOCAL
# 5       Decision Tree Regressor                   LOCAL
# 6             Linear Regression                   LOCAL

# %% [markdown]
# # 6. Feature Scaling

# %%
scaller = StandardScaler()
x_train_sc = scaller.fit_transform(X_train)
x_test_sc = scaller.transform(X_test)
x_train_sc[0:10,:]
# Out:
# array([[ 1.16591877e+00, -1.04064318e+00,  9.35849042e-01,
#         -3.76704338e+00, -6.43848689e-01, -3.89447874e-01,
#         -5.76348029e-02],
#        [ 1.16591877e+00, -1.16758995e+00, -9.24357419e-01,
#          2.65460176e-01, -6.43848689e-01,  3.36856102e-01,
#          7.08048762e-01],
#        [-4.26849632e-01,  1.01877812e-01,  9.35849042e-01,
#          2.65460176e-01,  9.59582180e-01, -3.84621934e-01,
#         -1.67785772e-01],
#        [ 5.28811408e-01, -1.19297931e+00,  9.35849042e-01,
#          2.65460176e-01, -6.43848689e-01, -1.31361539e+00,
#         -1.25138473e+00],
#        [ 8.47365088e-01, -7.86749623e-01, -9.24357419e-01,
#          2.65460176e-01,  2.56301305e+00,  5.39545584e-01,
#          1.92776925e+00],
#        [ 8.47365088e-01, -1.52015741e-01, -9.24357419e-01,
#          2.65460176e-01, -6.43848689e-01, -2.66386403e-01,
#          2.39683260e-01],
#        [ 1.48447245e+00, -1.57381964e+00,  9.35849042e-01,
#          2.65460176e-01, -6.43848689e-01, -3.89447874e-01,
#         -5.76348029e-02],
#        [ 1.16591877e+00, -1.54261612e+00,  9.35849042e-01,
#          2.65460176e-01, -6.43848689e-01,  3.32030162e-01,
#          1.00088914e+00],
#        [ 5.28811408e-01,  1.01877812e-01, -9.24357419e-01,
#          2.65460176e-01,  9.59582180e-01,  3.36856102e-01,
#          7.09839834e-01],
#        [ 1.16591877e+00, -1.16758995e+00,  9.35849042e-01,
#          2.65460176e-01, -6.43848689e-01, -3.89447874e-01,
#         -2.11155025e-03]])

# %%
fit_and_score(models, x_train_sc, x_test_sc, Y_train, Y_test)
# Out:
# 2024/12/07 22:21:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Linear Regression at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/ddb20356b1664c48a0045677092f8e20
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:21:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Decision Tree Regressor at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/d85b4c5b29ef47eba7726d8892baa534
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:22:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest Regressor at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/18cf869f0707487194600bb48843d84d
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0
# 2024/12/07 22:31:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Gradient Boosting Regression at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0/runs/ccf792253d924e61be1d321c92797fda
# 🧪 View experiment at: https://dagshub.com/WajihHlaili/my-first-repo.mlflow/#/experiments/0

# %%
# Best model
all_experiments = [exp.experiment_id for exp in mlflow.search_experiments()]
df_mlflow = mlflow.search_runs(experiment_ids=all_experiments,filter_string="metrics.Accuracy <1")
run_id = df_mlflow.loc[df_mlflow['metrics.Accuracy'].idxmax()]['run_id']
print(run_id)
# Out:
# ccf792253d924e61be1d321c92797fda

# %%
df_mlflow
# Out:
#                              run_id experiment_id    status  \
# 0  ccf792253d924e61be1d321c92797fda             0  FINISHED
# 1  18cf869f0707487194600bb48843d84d             0  FINISHED
# 2  d85b4c5b29ef47eba7726d8892baa534             0  FINISHED
# 3  ddb20356b1664c48a0045677092f8e20             0  FINISHED
# 4  c89eafeece5f4c8b8e702a8eefc137a9             0  FINISHED
# 5  a492256eadbe4c088323bcf9525da7ab             0  FINISHED
# 6  48a6cac8763c49f88f8df96798bae95b             0  FINISHED
# 7  13d0a7cec2b942e085e463ba28ebfd19             0  FINISHED
# 8  9bb00c896c3243a9856198374f461027             0  FINISHED
# 9  cebf468924d945bf90f50797a29650cf             0  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 1  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 2  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 3  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 4  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 5  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 6  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 7  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 8  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
# 9  mlflow-artifacts:/42e87a96dccf4c2193bb7c072066...
#
#                         start_time                         end_time  \
# 0 2024-12-07 21:30:52.084000+00:00 2024-12-07 21:31:20.121000+00:00
# 1 2024-12-07 21:22:01.227000+00:00 2024-12-07 21:30:51.462000+00:00
# 2 2024-12-07 21:21:33.273000+00:00 2024-12-07 21:22:00.733000+00:00
# 3 2024-12-07 21:21:14.212000+00:00 2024-12-07 21:21:32.770000+00:00
# 4 2024-12-07 21:19:34.510000+00:00 2024-12-07 21:19:57.759000+00:00
# 5 2024-12-07 21:11:32.861000+00:00 2024-12-07 21:19:34.015000+00:00
# 6 2024-12-07 21:11:01.074000+00:00 2024-12-07 21:11:32.290000+00:00
# 7 2024-12-07 21:10:42.934000+00:00 2024-12-07 21:11:00.568000+00:00
# 8 2024-12-07 21:02:00.166000+00:00 2024-12-07 21:02:29.155000+00:00
# 9 2024-12-07 21:01:38.284000+00:00 2024-12-07 21:01:59.662000+00:00
#
#     metrics.MAE  metrics.Accuracy   metrics.RMSE   metrics.MSE  metrics.R2  \
# 0  49623.023132          0.894397   68117.703049  4.640021e+09    0.909106
# 1  23383.290254          0.883772   34630.083023  1.199243e+09    0.976508
# 2   6479.951804          0.811390   21530.457438  4.635606e+08    0.990919
# 3  95538.933626          0.730273  120960.509958  1.463144e+10    0.713383
# 4  49623.023132          0.894397   68117.703049  4.640021e+09    0.909106
# 5  23367.113732          0.883039   34615.297654  1.198219e+09    0.976528
# 6   6479.951804          0.808349   21530.457438  4.635606e+08    0.990919
# 7  95538.933626          0.730273  120960.509958  1.463144e+10    0.713383
# 8   6479.951804          0.808349   21530.457438  4.635606e+08    0.990919
# 9  95538.933626          0.730273  120960.509958  1.463144e+10    0.713383
#
#     params.data_url params.random_state params.tol params.validation_fraction  \
# 0  data_cleaned.csv                   0     0.0001                        0.1
# 1  data_cleaned.csv                None       None                       None
# 2  data_cleaned.csv                None       None                       None
# 3  data_cleaned.csv                None       None                       None
# 4  data_cleaned.csv                   0     0.0001                        0.1
# 5  data_cleaned.csv                None       None                       None
# 6  data_cleaned.csv                None       None                       None
# 7  data_cleaned.csv                None       None                       None
# 8  data_cleaned.csv                None       None                       None
# 9  data_cleaned.csv                None       None                       None
#
#   params.verbose params.min_weight_fraction_leaf params.max_depth  \
# 0              0                             0.0                3
# 1              0                             0.0             None
# 2           None                             0.0             None
# 3           None                            None             None
# 4              0                             0.0                3
# 5              0                             0.0             None
# 6           None                             0.0             None
# 7           None                            None             None
# 8           None                             0.0             None
# 9           None                            None             None
#
#   params.max_features params.ccp_alpha params.criterion  \
# 0                None              0.0     friedman_mse
# 1                 1.0              0.0    squared_error
# 2                None              0.0    squared_error
# 3                None             None             None
# 4                None              0.0     friedman_mse
# 5                 1.0              0.0    squared_error
# 6                None              0.0    squared_error
# 7                None             None             None
# 8                None              0.0    squared_error
# 9                None             None             None
#
#   params.min_samples_leaf params.min_samples_split params.subsample  \
# 0                       1                        2              1.0
# 1                       1                        2             None
# 2                       1                        2             None
# 3                    None                     None             None
# 4                       1                        2              1.0
# 5                       1                        2             None
# 6                       1                        2             None
# 7                    None                     None             None
# 8                       1                        2             None
# 9                    None                     None             None
#
#      params.loss params.max_leaf_nodes params.data_version  \
# 0  squared_error                  None                v1.0
# 1           None                  None                v1.0
# 2           None                  None                v1.0
# 3           None                  None                v1.0
# 4  squared_error                  None                v1.0
# 5           None                  None                v1.0
# 6           None                  None                v1.0
# 7           None                  None                v1.0
# 8           None                  None                v1.0
# 9           None                  None                v1.0
#
#   params.n_iter_no_change params.input_rows params.init params.alpha  \
# 0                    None              6475        None          0.9
# 1                    None              6475        None         None
# 2                    None              6475        None         None
# 3                    None              6475        None         None
# 4                    None              6475        None          0.9
# 5                    None              6475        None         None
# 6                    None              6475        None         None
# 7                    None              6475        None         None
# 8                    None              6475        None         None
# 9                    None              6475        None         None
#
#   params.min_impurity_decrease params.n_estimators params.learning_rate  \
# 0                          0.0                 500                  0.1
# 1                          0.0                 100                 None
# 2                          0.0                None                 None
# 3                         None                None                 None
# 4                          0.0                 500                  0.1
# 5                          0.0                 100                 None
# 6                          0.0                None                 None
# 7                         None                None                 None
# 8                          0.0                None                 None
# 9                         None                None                 None
#
#   params.warm_start params.input_cols params.monotonic_cst params.bootstrap  \
# 0             False                 8                 None             None
# 1             False                 8                 None             True
# 2              None                 8                 None             None
# 3              None                 8                 None             None
# 4             False                 8                 None             None
# 5             False                 8                 None             True
# 6              None                 8                 None             None
# 7              None                 8                 None             None
# 8              None                 8                 None             None
# 9              None                 8                 None             None
#
#   params.oob_score params.max_samples params.n_jobs params.splitter  \
# 0             None               None          None            None
# 1            False               None          None            None
# 2             None               None          None            best
# 3             None               None          None            None
# 4             None               None          None            None
# 5            False               None          None            None
# 6             None               None          None            best
# 7             None               None          None            None
# 8             None               None          None            best
# 9             None               None          None            None
#
#   params.copy_X params.fit_intercept params.positive tags.train_features_name  \
# 0          None                 None            None                  X_train
# 1          None                 None            None                  X_train
# 2          None                 None            None                  X_train
# 3          True                 True           False                  X_train
# 4          None                 None            None                  X_train
# 5          None                 None            None                  X_train
# 6          None                 None            None                  X_train
# 7          True                 True           False                  X_train
# 8          None                 None            None                  X_train
# 9          True                 True           False                  X_train
#
#                      tags.model tags.train_label_name  \
# 0  Gradient Boosting Regression               Y_train
# 1       Random Forest Regressor               Y_train
# 2       Decision Tree Regressor               Y_train
# 3             Linear Regression               Y_train
# 4  Gradient Boosting Regression               Y_train
# 5       Random Forest Regressor               Y_train
# 6       Decision Tree Regressor               Y_train
# 7             Linear Regression               Y_train
# 8       Decision Tree Regressor               Y_train
# 9             Linear Regression               Y_train
#
#                              tags.mlflow.source.name  \
# 0  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 1  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 2  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 3  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 4  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 5  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 6  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 7  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 8  C:\Users\wajih\AppData\Roaming\Python\Python31...
# 9  C:\Users\wajih\AppData\Roaming\Python\Python31...
#
#                        tags.mlflow.log-model.history tags.mlflow.user  \
# 0  [{"run_id": "ccf792253d924e61be1d321c92797fda"...      wajihhlaili
# 1  [{"run_id": "18cf869f0707487194600bb48843d84d"...      wajihhlaili
# 2  [{"run_id": "d85b4c5b29ef47eba7726d8892baa534"...      wajihhlaili
# 3  [{"run_id": "ddb20356b1664c48a0045677092f8e20"...      wajihhlaili
# 4  [{"run_id": "c89eafeece5f4c8b8e702a8eefc137a9"...      wajihhlaili
# 5  [{"run_id": "a492256eadbe4c088323bcf9525da7ab"...      wajihhlaili
# 6  [{"run_id": "48a6cac8763c49f88f8df96798bae95b"...      wajihhlaili
# 7  [{"run_id": "13d0a7cec2b942e085e463ba28ebfd19"...      wajihhlaili
# 8  [{"run_id": "9bb00c896c3243a9856198374f461027"...      wajihhlaili
# 9  [{"run_id": "cebf468924d945bf90f50797a29650cf"...      wajihhlaili
#
#             tags.mlflow.runName tags.mlflow.source.type
# 0  Gradient Boosting Regression                   LOCAL
# 1       Random Forest Regressor                   LOCAL
# 2       Decision Tree Regressor                   LOCAL
# 3             Linear Regression                   LOCAL
# 4  Gradient Boosting Regression                   LOCAL
# 5       Random Forest Regressor                   LOCAL
# 6       Decision Tree Regressor                   LOCAL
# 7             Linear Regression                   LOCAL
# 8       Decision Tree Regressor                   LOCAL
# 9             Linear Regression                   LOCAL

# %% [markdown]
# <h2 style="text-align:right;">Passer à l'étape 4 ...</h2>
